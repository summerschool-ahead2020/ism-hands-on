# %% [markdown]
# ### AMOL SPEX dust model
#
# In order to study the dust in the spectra of X-ray binaries we want to analyze the dust with a dedicated model. This model is called amol and contains the edges of lab measurements of interstellar dust analogues, which were converted to interstellar dust models.
#
# In this example we use the spectrum of GX 17+2 to test the amol model and to try and fit the Si K-edge.

# %%
from pyspex import spex
s=spex.Session()
# Out:
#  Welcome jellep to SPEX version 3.07.03
#
#  NEW in this version of SPEX:
# 01-12-2022 Fixed issue with plot cap command
# 05-12-2022 Fixed issue with knak model
# 22-03-2023 Fixed issue with treatment of bad quality bins in trafo
# 23-03-2023 Fixed small issues in the pyspex interface
#
#  Currently using SPEXACT version 2.07.00. Type `help var calc` for details.

# %%
# %matplotlib inline

# %% [markdown]
# Here we read in the data from Chandra HETG. You can find the data in the spectra folder. Load the res and spo file of GX 17+2. The Chandra HETG data contain both the HEG and MEG grating spectra. The MEG spectrum is in region 1, the HEG in region 2 and both spectra are stored in the same sector, sector 1.

# %%
s.data('gx17/GX_17.res','gx17/GX_17.spo')
# Out:
# 0

# %% [markdown]
# Plot the spectra.

# %%
plt = s.plot_data(xlog=True, ylog=True, show=True)

# %% [markdown]
# Before fitting the edge, it is important to bin the spectrum. Ignore parts of the data where the grating is not sensitive/ where the telescope has little effective area:
# ign 7:1e4 u k  (here you ignore all the data beyond 7 keV)
# ign 1e-4:1.3 u k (here you ignore all the data below 1 keV)
# ign ins 1 region 2 1.5:1e4 u k ( here you ignore all the data of the MEG grating about 1.5 kev). We take this last step because the MEG grating is heavily depleted due to pile-up. The command s.bin(1, 1, 1, 7, 3, 'kev') rebins the data in this region with a factor of 3.

# %%
s.ignore(1, 1, 7.0, 1e4, 'kev')
s.ignore(1, 2, 1.5, 1e4, 'kev')
s.ignore(1, 1, 1e-4, 1.3, 'kev')
s.ignore(1, 2, 1e-4, 1.3, 'kev')
s.bin(1, 2, 1, 7, 3, 'kev')
s.bin(1, 1, 1, 7, 3, 'kev')

# %% [markdown]
# Plot again and take a look at the resulting spectrum.

# %%
plt = s.plot_data(xlog=True, ylog=True, show=True)

# %%
import numpy

# %% [markdown]
# Now we have correctly binned the spectrum. The Si K-edge around 1.8 keV is well sampled. Since we will closely look at variation in the area around the edge, this needs to be . Sometimes it may help to sample the data around the edge a bit courser to increase the number of photons in the bin. In this way we can reduce uncertainties on the measurements, but you pay for it in resolution, so it is only useful when you don’t need this information.

# %% [markdown]
# #### We can continue by defining models:
# We are modelling an X-ray binary, so we can either use a few simple models,
# such as a blackbody and power law model or we can make it a bit more sophisticated
# and choose a disk blackbody model in combination with a comptonization model. Here we will use a
# bb and po model to describe the source. These models take the least computational time, but they are not necessarily
# the best fitting model for the binary.

# %%
s.com('bb')
s.com('po')
# Out:
#  You have defined    1 component.
#  You have defined    2 components.

# %% [markdown]
# The light is then absorbed by cold gas along the line of sight.
# We define this as a “hot” model with a cold (i.e. very low) temperature.
# You cannot put the temperature to zero, because then SPEX cannot calculate anything anymore.
# So we define: com hot

# %%
s.com('hot')
# Out:
#  You have defined    3 components.

# %% [markdown]
# We set a distance: dist 12.6 kpc in this case

# %%
s.dist(1, 12.6, 'kpc')
# Out:
#  Distances assuming H0 =  70.0 km/s/Mpc, Omega_m = 0.300 Omega_Lambda = 0.700 Omega_r = 0.000
# Sector       m      A.U.        ly        pc       kpc       Mpc  redshift        cz   age(yr)
# ----------------------------------------------------------------------------------------------
#    1 3.888E+20 2.599E+09 4.110E+04 1.260E+04   12.6000 1.260E-02    0.0000       0.9 4.110E+04
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# We then relate the models, so SPEX knows in what order it needs to use them:
# com rel 1:2 3 (if you use SPEX from the command line)
# where 1 is the bb model, 2 the po model and 3 the hot model.

# %%
s.com_rel(1, 1, numpy.array([3]))

# %%
s.com_rel(1, 2, numpy.array([3]))

# %% [markdown]
# With the command: model show, you can inspect the model

# %%
s.command('model show')
# Out:
# --------------------------------------------------------------------------------
#  Number of sectors         :     1
#  Sector:    1 Number of model components:     3
#     Nr.    1: bb  [3 ]
#     Nr.    2: pow [3 ]
#     Nr.    3: hot
# 0

# %% [markdown]
# We now need to set some values to the models.
# This is a bit of trial and error usually.
# Try values that already seem to fit the X-ray binary,
# but still leave freedom to the fit to find a best-fitting set of values.
# For this X-ray binary I give you some starting values:

# %%
s.par(1, 1, 't', 1.5, thawn=True)
s.par(1, 1, 'n', 1.e-7, thawn=True)

s.par(1, 2, 'n', 100, thawn = True)
s.par(1, 2, 'gamm', 1.5, thawn = True)

s.par(1, 3, 'nh', 2.4e-2, thawn = True)
s.par(1, 3, 't', 8e-6, thawn = False)

# %% [markdown]
# Calculate with s.calc(), plot the result and inspect if you think the model is good enough to fit.

# %%
s.calc()
plt = s.plot_data(xlog=True, ylog=True, show=True)

# %% [markdown]
# With the command s.fit(), you start fitting. If you use SPEX from the command line,
# you can use the command fit print 1 to see all the intermediate fitting steps and inspect how the fit converges.

# %%
s.fit()
print(s.fit_cstat())
# Out:
#  fit iter  100
#   1.140309E+06          6  1.000E-07   1.50       100.       1.50      2.400E-02
#  You cannot plot this frame since nothing is defined
#
#    391305.             13  1.293E-07   1.63       122.       1.32      2.112E-02
#  You cannot plot this frame since nothing is defined
#
#    26944.3             19  1.936E-07   1.44       193.       1.07      2.004E-02
#  You cannot plot this frame since nothing is defined
#
#    18965.7             26  2.392E-07   1.27       233.       1.15      2.156E-02
#  You cannot plot this frame since nothing is defined
#
#    14680.6             32  3.380E-07   1.12       317.       1.36      2.522E-02
#  You cannot plot this frame since nothing is defined
#
#    7982.40             38  4.462E-07   1.02       414.       1.49      2.794E-02
#  You cannot plot this frame since nothing is defined
#
#    5270.32             44  6.051E-07  0.888       472.       1.51      2.929E-02
#  You cannot plot this frame since nothing is defined
#
#    5049.47             50  9.575E-07  0.843       410.       1.44      2.856E-02
#  You cannot plot this frame since nothing is defined
#
#    4805.57             56  1.299E-06  0.835       327.       1.34      2.742E-02
#  You cannot plot this frame since nothing is defined
#
#    4298.02             63  1.444E-06  0.836       291.       1.27      2.677E-02
#  You cannot plot this frame since nothing is defined
#
#    4251.21             70  1.491E-06  0.836       278.       1.24      2.654E-02
#  You cannot plot this frame since nothing is defined
#
#    4218.65             76  1.584E-06  0.833       258.       1.21      2.621E-02
#  You cannot plot this frame since nothing is defined
#
#    4214.29             82  1.755E-06  0.828       223.       1.13      2.562E-02
#  You cannot plot this frame since nothing is defined
#
#    4123.38             88  1.838E-06  0.830       203.       1.09      2.524E-02
#  You cannot plot this frame since nothing is defined
#
#    4095.61             95  1.902E-06  0.830       189.       1.05      2.497E-02
#  You cannot plot this frame since nothing is defined
#
#    4086.02            101  2.023E-06  0.829       165.      0.982      2.451E-02
#  You cannot plot this frame since nothing is defined
#
#    4034.30            107  2.082E-06  0.831       152.      0.938      2.424E-02
#  You cannot plot this frame since nothing is defined
#
#    4015.96            114  2.131E-06  0.832       142.      0.901      2.401E-02
#  You cannot plot this frame since nothing is defined
#
#    4012.53            120  2.224E-06  0.833       124.      0.835      2.364E-02
#  You cannot plot this frame since nothing is defined
#
#    3972.95            126  2.268E-06  0.834       115.      0.795      2.345E-02
#  You cannot plot this frame since nothing is defined
#
#    3960.77            133  2.306E-06  0.835       107.      0.761      2.328E-02
#  You cannot plot this frame since nothing is defined
#
#    3958.67            139  2.376E-06  0.837       94.7      0.699      2.301E-02
#  You cannot plot this frame since nothing is defined
#
#    3932.07            145  2.413E-06  0.838       88.1      0.660      2.286E-02
#  You cannot plot this frame since nothing is defined
#
#    3925.57            152  2.432E-06  0.838       84.9      0.639      2.278E-02
#  You cannot plot this frame since nothing is defined
#
#    3919.39            158  2.466E-06  0.839       78.9      0.603      2.265E-02
#  You cannot plot this frame since nothing is defined
#
#    3912.40            164  2.503E-06  0.841       72.8      0.562      2.252E-02
#  You cannot plot this frame since nothing is defined
#
#    3905.68            170  2.540E-06  0.842       67.0      0.520      2.239E-02
#  You cannot plot this frame since nothing is defined
#
#    3900.29            176  2.576E-06  0.843       61.5      0.476      2.228E-02
#  You cannot plot this frame since nothing is defined
#
#    3896.25            182  2.612E-06  0.844       56.3      0.430      2.217E-02
#  You cannot plot this frame since nothing is defined
#
#    3893.08            188  2.648E-06  0.845       51.5      0.385      2.208E-02
#  You cannot plot this frame since nothing is defined
#
#    3892.01            194  2.684E-06  0.846       47.0      0.338      2.199E-02
#  You cannot plot this frame since nothing is defined
#
#    3887.79            200  2.698E-06  0.846       46.6      0.330      2.201E-02
#  You cannot plot this frame since nothing is defined
#
# --------------------------------------------------------------------------------------------------
# sect comp mod  acro parameter with unit     value      status    minimum   maximum lsec lcom lpar
#
#    1    1 bb   norm Area (1E16 m**2)     2.6970513E-06 thawn     0.0      1.00E+20
#    1    1 bb   t    Temperature (keV)    0.8449900     thawn    1.00E-04  1.00E+03
#
#    1    2 pow  norm Norm (1E44 ph/s/keV)  47.33759     thawn     0.0      1.00E+20
#    1    2 pow  gamm Photon index         0.3384236     thawn    -10.       10.
#    1    2 pow  dgam Photon index break    0.000000     frozen   -10.       10.
#    1    2 pow  e0   Break energy (keV)   1.0000000E+10 frozen    0.0      1.00E+20
#    1    2 pow  b    Break strength        0.000000     frozen    0.0       10.
#    1    2 pow  type Type of norm          0.000000     frozen    0.0       1.0
#    1    2 pow  elow Low flux limit (keV)  2.000000     frozen   1.00E-20  1.00E+10
#    1    2 pow  eupp Upp flux limit (keV)  10.00000     frozen   1.00E-20  1.00E+10
#    1    2 pow  lum  Luminosity (1E30 W)   19.49581     frozen    0.0      1.00E+20
#
#    1    3 hot  nh   X-Column (1E28/m**2) 2.2030743E-02 thawn     0.0      1.00E+20
#    1    3 hot  t    Temperature (keV)    8.0000000E-06 frozen   1.00E-06  1.00E+03
#    1    3 hot  rt   T(balance) / T(spec)  1.000000     frozen   1.00E-04  1.00E+04
#    1    3 hot  hden Hyd dens (1E20/m**3) 9.9999998E-15 frozen   1.00E-22  1.00E+10
#    1    3 hot  fcov Covering fraction     1.000000     frozen    0.0       1.0
#    1    3 hot  v    RMS Velocity (km/s)   100.0000     frozen    0.0      3.00E+05
#    1    3 hot  rms  RMS blend    (km/s)   0.000000     frozen    0.0      1.00E+05
#    1    3 hot  dv   Vel. separ. (km/s)    100.0000     frozen    0.0      1.00E+05
#    1    3 hot  zv   Average vel. (km/s)   0.000000     frozen  -1.00E+05  1.00E+05
#    1    3 hot  ref  Reference atom        1.000000     frozen    1.0       30.
#    1    3 hot  01   Abundance H           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  02   Abundance He          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  03   Abundance Li          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  04   Abundance Be          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  05   Abundance B           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  06   Abundance C           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  07   Abundance N           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  08   Abundance O           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  09   Abundance F           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  10   Abundance Ne          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  11   Abundance Na          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  12   Abundance Mg          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  13   Abundance Al          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  14   Abundance Si          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  15   Abundance P           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  16   Abundance S           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  17   Abundance Cl          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  18   Abundance Ar          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  19   Abundance K           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  20   Abundance Ca          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  21   Abundance Sc          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  22   Abundance Ti          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  23   Abundance V           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  24   Abundance Cr          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  25   Abundance Mn          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  26   Abundance Fe          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  27   Abundance Co          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  28   Abundance Ni          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  29   Abundance Cu          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  30   Abundance Zn          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  file File electr.distrib.
#    1    3 hot  b    B field (Tesla)       0.000000     frozen    0.0      1.00E+05
#
#
# Instrument     1 region    1 has norm    1.00000E+00 and is frozen
# Instrument     1 region    2 has norm    1.00000E+00 and is frozen
#
# --------------------------------------------------------------------------------
#  Fluxes and restframe luminosities between   2.0000     and    10.000     keV
#
#  sect comp mod   photon flux   energy flux nr of photons    luminosity
#               (phot/m**2/s)      (W/m**2)   (photons/s)           (W)
#     1    1 bb     7442.20      4.335303E-12  1.921783E+46  1.049056E+31
#     1    2 pow    9909.75      9.446091E-12  2.150655E+46  1.949576E+31
#
# --------------------------------------------------------------------------------
#  Fit method        : Classical Levenberg-Marquardt
#  Fit statistic     : C-statistic
#  Fit statistic used:      3887.79
#  C-statistic       :      3887.79
#  Expected C-stat   :      1121.47 +/-        47.37
#  Chi-squared value :      2581.08
#  Degrees of freedom:      1116
#  W-statistic       :         0.00
#
# (3887.7861328125, 1116)

# %%
plt = s.plot_data(xlog=True, ylog=True, show=True)

# %% [markdown]
# Let's take a look at the area around the Silicon K-edge:

# %%
(pdata, plt) = s.plot_data(xlog=True,ylog=True,show=False)
plt.xlim(1.7,2.2)
plt.show()

# %% [markdown]
# # Amol
# If you are happy with the fit of the continuum (when is a fit a good fit?) , you can add another model. We now want to specifically fit the dust features of the edges.
# In this spectrum we observe a prominent Si K-edge feature.
# Define the amol model and relate the models again.

# %%
s.com('amol')
# Out:
#  You have defined    4 components.

# %%
s.com_rel(1, 1, numpy.array([3,4]))
s.com_rel(1, 2, numpy.array([3,4]))

# %% [markdown]
# With par sho you can inspect the parameters in the amol model.
# The values i1 to i4 are slots where you can input different dust species.
# For instance the value 4103 stands for olivine and 4234 for pyroxene.
# Try if you can fit these silicate models to the spectrum.
# A full list is available in SPEX, this index file is also stored in this repository.
# The values n1 to n4 are the corresponding values of the abundances of these dust species.
# Usually a starting value of 1e-7 is a good first guess.

# %%
s.par(1, 4, 'i1', 4103, thawn = False)
s.par(1, 4, 'n1', 1e-7, thawn = True)
s.par(1, 4, 'i2', 4234 , thawn = False)
s.par(1, 4, 'n2', 1e-7, thawn = True)

# %% [markdown]
# Because silicon, magnesium, oxygen and iron are now depleted into dust,
# we need to make some changes to the hot model.
# The elements should be thawned and we will lower the default gas values
# and implement ranges for the depletion.

# %%
s.par(1, 3, '08', 0.7, thawn = True)
s.par(1, 3, '12', 0.1, thawn = True)
s.par(1, 3, '14', 0.1, thawn = True)
s.par(1, 3, '26', 0.1, thawn = True)
s.par_free(1, 3, '08')
s.command('par 1 3 08 range 0.58 0.98')
s.command('par 1 3 12 range 0.05 0.98')
s.command('par 1 3 14 range 0.04 0.59')
s.command('par 1 3 26 range 0.03 0.30')
s.calc()

# %% [markdown]
# Try to fit the spectrum and zoom in on the Si K-edge.
# Can you see the XAFS? What do you need to change in the cold gas model (hot)? Think about depletion!

# %%
s.fit()
print(s.fit_cstat())
# Out:
#  fit iter  100
#    52173.3             12  2.697E-06  0.845       47.3      0.338      2.203E-02
#                 0.700      0.100      0.100      0.100      1.000E-07  1.000E-07
#  You cannot plot this frame since nothing is defined
#
#    18210.4             25  2.798E-06  0.814       74.5      0.617      1.700E-02
#                 0.978      5.000E-02  4.000E-02  0.300      5.116E-07  4.582E-07
#  You cannot plot this frame since nothing is defined
#
#    4739.93             38  2.850E-06  0.812       78.3      0.581      1.900E-02
#                 0.980      5.000E-02  4.000E-02  0.300      5.593E-07  4.993E-07
#  You cannot plot this frame since nothing is defined
#
#    1559.05             50  2.880E-06  0.800       95.3      0.689      2.134E-02
#                 0.980      5.000E-02  4.000E-02  0.300      5.954E-07  4.979E-07
#  You cannot plot this frame since nothing is defined
#
#    1426.20             63  2.890E-06  0.798       99.3      0.699      2.148E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.018E-07  4.971E-07
#  You cannot plot this frame since nothing is defined
#
#    1426.12             75  2.873E-06  0.795       107.      0.737      2.158E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.208E-07  4.888E-07
#  You cannot plot this frame since nothing is defined
#
#    1422.86             87  2.863E-06  0.793       111.      0.754      2.163E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.310E-07  4.839E-07
#  You cannot plot this frame since nothing is defined
#
#    1422.23            100  2.854E-06  0.792       114.      0.768      2.167E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.385E-07  4.802E-07
#  You cannot plot this frame since nothing is defined
#
#    1422.08            112  2.835E-06  0.790       120.      0.794      2.176E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.521E-07  4.735E-07
#  You cannot plot this frame since nothing is defined
#
#    1421.30            124  2.826E-06  0.789       123.      0.806      2.180E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.595E-07  4.699E-07
#  You cannot plot this frame since nothing is defined
#
#    1421.20            137  2.820E-06  0.789       125.      0.815      2.182E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.643E-07  4.675E-07
#  You cannot plot this frame since nothing is defined
#
#    1421.19            149  2.811E-06  0.788       128.      0.825      2.186E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.698E-07  4.648E-07
#  You cannot plot this frame since nothing is defined
#
#    1421.17            161  2.815E-06  0.788       127.      0.822      2.184E-02
#                 0.980      5.000E-02  4.000E-02  0.300      6.689E-07  4.652E-07
#  You cannot plot this frame since nothing is defined
#
#  Parameter    6 is at upper limit. Suggestion: fit again
#
#  Parameter    7 is at lower limit. Suggestion: fit again
#
#  Parameter    8 is at lower limit. Suggestion: fit again
#
#  Parameter    9 is at upper limit. Suggestion: fit again
#
# --------------------------------------------------------------------------------------------------
# sect comp mod  acro parameter with unit     value      status    minimum   maximum lsec lcom lpar
#
#    1    1 bb   norm Area (1E16 m**2)     2.8147758E-06 thawn     0.0      1.00E+20
#    1    1 bb   t    Temperature (keV)    0.7880990     thawn    1.00E-04  1.00E+03
#
#    1    2 pow  norm Norm (1E44 ph/s/keV)  126.8527     thawn     0.0      1.00E+20
#    1    2 pow  gamm Photon index         0.8217982     thawn    -10.       10.
#    1    2 pow  dgam Photon index break    0.000000     frozen   -10.       10.
#    1    2 pow  e0   Break energy (keV)   1.0000000E+10 frozen    0.0      1.00E+20
#    1    2 pow  b    Break strength        0.000000     frozen    0.0       10.
#    1    2 pow  type Type of norm          0.000000     frozen    0.0       1.0
#    1    2 pow  elow Low flux limit (keV)  2.000000     frozen   1.00E-20  1.00E+10
#    1    2 pow  eupp Upp flux limit (keV)  10.00000     frozen   1.00E-20  1.00E+10
#    1    2 pow  lum  Luminosity (1E30 W)   22.09768     frozen    0.0      1.00E+20
#
#    1    3 hot  nh   X-Column (1E28/m**2) 2.1844337E-02 thawn     0.0      1.00E+20
#    1    3 hot  t    Temperature (keV)    8.0000000E-06 frozen   1.00E-06  1.00E+03
#    1    3 hot  rt   T(balance) / T(spec)  1.000000     frozen   1.00E-04  1.00E+04
#    1    3 hot  hden Hyd dens (1E20/m**3) 9.9999998E-15 frozen   1.00E-22  1.00E+10
#    1    3 hot  fcov Covering fraction     1.000000     frozen    0.0       1.0
#    1    3 hot  v    RMS Velocity (km/s)   100.0000     frozen    0.0      3.00E+05
#    1    3 hot  rms  RMS blend    (km/s)   0.000000     frozen    0.0      1.00E+05
#    1    3 hot  dv   Vel. separ. (km/s)    100.0000     frozen    0.0      1.00E+05
#    1    3 hot  zv   Average vel. (km/s)   0.000000     frozen  -1.00E+05  1.00E+05
#    1    3 hot  ref  Reference atom        1.000000     frozen    1.0       30.
#    1    3 hot  01   Abundance H           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  02   Abundance He          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  03   Abundance Li          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  04   Abundance Be          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  05   Abundance B           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  06   Abundance C           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  07   Abundance N           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  08   Abundance O          0.9800000     thawn    0.58      0.98
#    1    3 hot  09   Abundance F           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  10   Abundance Ne          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  11   Abundance Na          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  12   Abundance Mg         5.0000001E-02 thawn    5.00E-02  0.98
#    1    3 hot  13   Abundance Al          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  14   Abundance Si         3.9999999E-02 thawn    4.00E-02  0.59
#    1    3 hot  15   Abundance P           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  16   Abundance S           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  17   Abundance Cl          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  18   Abundance Ar          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  19   Abundance K           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  20   Abundance Ca          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  21   Abundance Sc          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  22   Abundance Ti          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  23   Abundance V           1.000000     frozen    0.0      1.00E+10
#    1    3 hot  24   Abundance Cr          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  25   Abundance Mn          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  26   Abundance Fe         0.3000000     thawn    3.00E-02  0.30
#    1    3 hot  27   Abundance Co          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  28   Abundance Ni          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  29   Abundance Cu          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  30   Abundance Zn          1.000000     frozen    0.0      1.00E+10
#    1    3 hot  file File electr.distrib.
#    1    3 hot  b    B field (Tesla)       0.000000     frozen    0.0      1.00E+05
#
#    1    4 amol n1   Column 1 (1E28/m**2) 6.6885531E-07 thawn     0.0      1.00E+20
#    1    4 amol n2   Column 1 (1E28/m**2) 4.6524002E-07 thawn     0.0      1.00E+20
#    1    4 amol n3   Column 1 (1E28/m**2)  0.000000     frozen    0.0      1.00E+20
#    1    4 amol n4   Column 1 (1E28/m**2)  0.000000     frozen    0.0      1.00E+20
#    1    4 amol i1   Molecule index 1      4103.000     frozen    0.0      1.00E+04
#    1    4 amol i2   Molecule index 2      4234.000     frozen    0.0      1.00E+04
#    1    4 amol i3   Molecule index 3      0.000000     frozen    0.0      1.00E+04
#    1    4 amol i4   Molecule index 4      0.000000     frozen    0.0      1.00E+04
#    1    4 amol fcov Covering fraction     1.000000     frozen    0.0       1.0
#    1    4 amol zv   Average vel. (km/s)   0.000000     frozen  -1.00E+05  1.00E+05
#    1    4 amol 01   H  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 02   He column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 03   Li column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 04   Be column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 05   B  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 06   C  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 07   N  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 08   O  column (1E28 m-2) 4.0711411E-06 frozen    0.0      1.00E+10
#    1    4 amol 09   F  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 10   Ne column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 11   Na column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 12   Mg column (1E28 m-2) 1.4190986E-06 frozen    0.0      1.00E+10
#    1    4 amol 13   Al column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 14   Si column (1E28 m-2) 1.1340953E-06 frozen    0.0      1.00E+10
#    1    4 amol 15   P  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 16   S  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 17   Cl column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 18   Ar column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 19   K  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 20   Ca column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 21   Sc column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 22   Ti column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 23   V  column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 24   Cr column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 25   Mn column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 26   Fe column (1E28 m-2) 3.8385213E-07 frozen    0.0      1.00E+10
#    1    4 amol 27   Co column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 28   Ni column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 29   Cu column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#    1    4 amol 30   Zn column (1E28 m-2)  0.000000     frozen    0.0      1.00E+10
#
#
# Instrument     1 region    1 has norm    1.00000E+00 and is frozen
# Instrument     1 region    2 has norm    1.00000E+00 and is frozen
#
# --------------------------------------------------------------------------------
#  Fluxes and restframe luminosities between   2.0000     and    10.000     keV
#
#  sect comp mod   photon flux   energy flux nr of photons    luminosity
#               (phot/m**2/s)      (W/m**2)   (photons/s)           (W)
#     1    1 bb     5443.11      3.088070E-12  1.496279E+46  7.889629E+30
#     1    2 pow    11677.2      1.036432E-11  2.675372E+46  2.209753E+31
#
# --------------------------------------------------------------------------------
#  Fit method        : Classical Levenberg-Marquardt
#  Fit statistic     : C-statistic
#  Fit statistic used:      1421.17
#  C-statistic       :      1421.17
#  Expected C-stat   :      1121.47 +/-        47.37
#  Chi-squared value :      1420.78
#  Degrees of freedom:      1110
#  W-statistic       :         0.00
#
# (1421.1727294921875, 1110)

# %%
(pdata, plt) = s.plot_data(xlog=True,ylog=True,show=False)
plt.xlim(1.7,2.2)
plt.show()

# %%
# Define a function to plot spectrum in photon flux
def plot_flux(xlog=False,ylog=False,wave=False):
    # Get plot data
    (data,plt) = s.plot_data(wave=wave,show=False)
    plt.clf()    
    
    fig, ax = plt.subplots()
    
    # Loop over instruments and regions
    for i in numpy.arange(data.ninst):
        for r in numpy.arange(data.inst[i].nreg):
            tabdata = data.inst[i].reg[r].tabdata
            
            # Calculate flux spectrum and other plotting arrays
            xerror = tabdata['X_ctr'] - tabdata['X_low']
            ydata = tabdata['Data'] * tabdata['1/Area']
            yerror = tabdata['Error'] * tabdata['1/Area']
            model = tabdata['Model'] * tabdata['1/Area']
            
            ax.errorbar(tabdata['X_ctr'], ydata, xerr=xerror, yerr=yerror, marker='', ls='', c='k')
            ax.step(tabdata['X_upp'], model, where='pre',c='r')
            
            if xlog:
                ax.set_xscale('log')

            if ylog:
                ax.set_yscale('log')
    
    # Set plot labels and format axes
    if wave:
        plt.xlabel('Wavelength ({0})'.format(tabdata['X_ctr'].unit.to_string('latex_inline')))
    else:
        plt.xlabel('Energy ({0})'.format(tabdata['X_ctr'].unit.to_string('latex_inline')))

    plt.ylabel('Flux ({0})'.format(ydata.unit.to_string('latex_inline')))

    if xlog:
        formatter = FuncFormatter(lambda y, _: '{:.16g}'.format(y))
        ax.xaxis.set_major_formatter(formatter)   
    
    return plt

# %%
plt=plot_flux()
plt.xlim(1.7,2.0)
plt.show()
